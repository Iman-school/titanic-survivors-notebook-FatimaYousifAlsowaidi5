# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic-passengers (2).csv' , sep=';')
df.head(20)
# Out:
#     PassengerId Survived  Pclass  \
# 0           343       No       2
# 1            76       No       3
# 2           641       No       3
# 3           568       No       3
# 4           672       No       1
# 5           105       No       3
# 6           576       No       3
# 7           382      Yes       3
# 8           228       No       3
# 9           433      Yes       2
# 10          135       No       2
# 11          294       No       3
# 12          755      Yes       2
# 13          595       No       2
# 14          127       No       3
# 15          434       No       3
# 16          378       No       1
# 17          533       No       3
# 18          666       No       2
# 19          225      Yes       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    male  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    male  25.0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
 import numpy as up 
#we select numeric colum in the dataframe 
numeric = df.select_dtypes(include=np.number)
numeric_columns = numeric.columns

# %%
#we fill the NoN values of numeric colums with the average value 
df['Age'].fillna(dfdf['Age'].mean(),inplace=True)
df.inf0()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_y/w0j4mywn3s312c66sxg5j7m40000gn/T/ipykernel_7967/2205986787.py in <module>
#       1 #we fill the NoN values of numeric colums with the average value
# ----> 2 df['Age'].fillna(dfdf['Age'].mean(),inplace=True)
#       3 df.inf0()
#
# NameError: name 'dfdf' is not defined

# %%
#print the numeric colums
numeric
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            343       2  28.0      0      0  13.0000
# 1             76       3  25.0      0      0   7.6500
# 2            641       3  20.0      0      0   7.8542
# 3            568       3  29.0      0      4  21.0750
# 4            672       1  31.0      1      0  52.0000
# ..           ...     ...   ...    ...    ...      ...
# 886           10       2  14.0      1      0  30.0708
# 887           61       3  22.0      0      0   7.2292
# 888          535       3  30.0      0      0   8.6625
# 889          102       3   NaN      0      0   7.8958
# 890          428       2  19.0      0      0  26.0000
#
# [891 rows x 6 columns]

# %%
df=df.fillna(df.mode().iloc[0])
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000  B96 B98        S
# 1    male  25.0      0      0      348123   7.6500    F G73        S
# 2    male  20.0      0      0      350050   7.8542  B96 B98        S
# 3  female  29.0      0      4      349909  21.0750  B96 B98        S
# 4    male  31.0      1      0  F.C. 12750  52.0000      B71        S

# %%
#Number of missing values in Age
df['Age'].isnull().sum()
# Out:
# 0

# %%
df.drop('cabin',axis=1,inplace=True)
df.into()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_y/w0j4mywn3s312c66sxg5j7m40000gn/T/ipykernel_7967/752527689.py in <module>
# ----> 1 df.drop('cabin',axis=1,inplace=True)
#       2 df.into()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...
